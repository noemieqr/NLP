# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import os
import json
import pickle
import copy
import random
import re
import pandas as pd
import numpy as np
from nltk import FreqDist
from gensim.models import Word2Vec, KeyedVectors
from keras.utils import to_categorical
from keras.preprocessing.text import text_to_word_sequence
from keras.preprocessing.sequence import pad_sequences
import sys
import json
import numpy as np
from gensim.models import Word2Vec
from gensim.utils import simple_preprocess
import math
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # 1. Pre Processing

# %%
def load_data(path):
    train = pd.read_csv(path+'/trainset.csv')
    dev = pd.read_csv(path+'/devset.csv')
    test = pd.read_csv(path+'/testset.csv')
    test_ref = pd.read_csv(path+'/testset_w_refs.csv')
    return (train, dev, test, test_ref)

# %%
train, dev, test, test_ref = load_data('../e2e-dataset')
print(train.shape)
print(dev.shape)
print(test_ref.shape)
print(test.shape)
# Out:
# (42061, 2)
# (4672, 2)
# (4693, 2)
# (630, 1)

# %%
use_pretrained_embeddings = True        # set to True to use a pre-trained word embedding model
use_split_mrs = False                        # set to True to split the test MRs before predicting
postprocess = True                      # set to False to skip the utterance post-processing
max_input_seq_len = 30                  # number of words the MRs should be truncated/padded to
max_output_seq_len = 50                 # number of words the utterances should be truncated/padded to
vocab_size = 10000                      # maximum vocabulary size of the utterances
num_variations = 3                      # number of MR permutations to consider for re-ranking
depth_enc = 1                           # number of LSTM layers in the encoder
depth_dec = 1                           # number of LSTM layers in the decoder
hidden_layer_size = 500                 # number of neurons in a single LSTM layer

# %%
def create_embeddings(file_paths, **params):
    class SentenceGenerator(object):
        def __init__(self, file_paths):
            self.file_paths = file_paths

        def __iter__(self):
            for file_path in self.file_paths:
                for line in open(file_path):
                    # tokenize
                    yield simple_preprocess(line)

    sentences = SentenceGenerator(file_paths)

    model = Word2Vec(sentences, **params)
    return model

# %%
def permute_input(mrs, sents, num_permutes):
   
    new_mr = []
    new_sent = []
    for x, mr in enumerate(mrs):
        sentence = sents[x]
        temp = []
        for slot_value in mr.split(','):
            sep_idx = slot_value.find('[')
            slot = slot_value[:sep_idx].strip()
            value = slot_value[sep_idx + 1:-1].strip()
            temp.append(slot + '[' + value + ']')
        
       # num_permutes= math.factorial(len(temp))
        for t in range(0, num_permutes):
            temptemp = copy.deepcopy(temp)
            random.shuffle(temptemp)
            curr_mr = ', '.join(temptemp)
            new_mr.append(curr_mr)
            new_sent.append(sentence)
            
    return new_mr, new_sent

# %%
def split_mrs(mrs, utterances, num_variations):

    new_mrs = []
    new_utterances = []
    groups = []
    group_id = 0

    for idx, mr in enumerate(mrs):
        utterance = utterances[idx]
        # do not split short MRs
        if len(mr) < 4:
            new_mrs.append(mr)
            new_utterances.append(utterance)
            continue

        slot_value_list = []
        name_slot = ()

        # parse the slot-value pairs
        for slot_value in mr.split(','):
            sep_idx = slot_value.find('[')
            slot = slot_value[:sep_idx].strip()
            value = slot_value[sep_idx + 1:-1].strip()

            if slot == 'name':
                name_slot = (slot, value)
            else:
                slot_value_list.append((slot, value))

        for i in range(num_variations):
            slot_value_list_copy = slot_value_list[:]
            random.shuffle(slot_value_list_copy)

            # distribute the slot-value pairs as multiple shorter MRs
            while len(slot_value_list_copy) > 0:
                # include the name slot by default in each subset
                mr_subset = [name_slot]
                # add up to two other slots to the subset
                for i in range(min(2, len(slot_value_list_copy))):
                    mr_subset.append(slot_value_list_copy.pop())
            
                new_mr = [s + '[' + v + ']' for s, v in mr_subset]
                new_mrs.append(', '.join(new_mr))
                new_utterances.append(utterance)
                groups.append(group_id)
            
            group_id += 1

    return new_mrs, new_utterances, groups

# %%
def preprocess_utterance(utterance):
    chars_to_filter = '.!"#$%&()*+,-/:;<=>?@[\\]^_`{|}~\t\n'
    return text_to_word_sequence(utterance, filters=chars_to_filter)

# %%
def delex_data(mrs, sentences, update_data_source=False,  split=True):

    delex_slots = ['name', 'food', 'near']

    for x, mr in enumerate(mrs):
       
        sentence = ' '.join(sentences[x])
    
        for slot_value in mr.split(','):
            sep_idx = slot_value.find('[')
            # parse the slot
            slot = slot_value[:sep_idx].strip()
            if slot in delex_slots:
                value = slot_value[sep_idx + 1:-1].strip()
                name = '&slot_val_{0}&'+slot
                sentence = sentence.replace(value.lower(), name)
                mr = mr.replace(value, name)

        sentences[x] = sentence.split()
        mrs[x] = mr

# %%
def add_padding(seq, padding_vec, max_seq_len):
    diff = max_seq_len - len(seq)
    if diff > 0:
        # pad short sequences
        return seq + [padding_vec for i in range(diff)]
    else:
        # truncate long sequences
        return seq[:max_seq_len]

# %%
# produce sequences of embedding vectors from the meaning representations
def seq_emb (data , embedding, vocab, max_input_seq_len , padding_vec):  
    data_seq=[]
    for mr in data:
        row_list = []
        for slot_value in mr.split(','):
            sep_idx = slot_value.find('[')
            # parse the slot and convert to embedding
            slot = slot_value[:sep_idx].strip()
            row_list.extend([embedding[slot_word] for slot_word in slot.split() if slot_word in vocab])
            # parse the value and convert to embedding
            value = slot_value[sep_idx + 1:-1].strip()
            row_list.extend([embedding[value_word] for value_word in value.split() if value_word in vocab])
        # add padding
        row_list = add_padding(row_list, padding_vec, max_input_seq_len)
        data_seq.append(row_list)
    
    return data_seq

# %%
 # produce sequences of one-hot vectors from the reference utterances
def seq_one_hot(y, y_word2idx, max_output_seq_len):

    y_seq = np.zeros((len(y), max_output_seq_len, len(y_word2idx)), dtype=np.int8)
    for i, utterance in enumerate(y):
        for j, word in enumerate(utterance):
            # truncate long utterances
            if j >= max_output_seq_len:
                break

            # represent each word with a one-hot vector
            if word == '.':
                y_seq[i][j][y_word2idx['-PERIOD-']] = 1
            elif word in y_word2idx:
                y_seq[i][j][y_word2idx[word]] = 1
            else:
                y_seq[i][j][y_word2idx['-NA-']] = 1

        # add padding for short utterances
        for j in range(len(utterance), max_output_seq_len):
            y_seq[i][j][y_word2idx['-PADDING-']] = 1

    return y_seq

# %%
def preprocess_data(train, dev, test_ref , vocab_size, max_input_seq_len, max_output_seq_len, num_variations, use_split_mrs):
    
    x_train = train.mr.tolist()
    y_train = train.ref.tolist()
    
    x_dev = dev.mr.tolist()
    y_dev = dev.ref.tolist()
    
    x_test_ref = test_ref.mr.tolist()
    y_test_ref = test_ref.ref.tolist()
    
    
    original_mrs_dev = copy.deepcopy(x_dev)
    original_sents_dev = copy.deepcopy(y_dev)
    
    original_mrs_test = copy.deepcopy(x_test_ref)
    original_sents_test = copy.deepcopy(y_test_ref)
    
    
    
    dev_groups = []
    test_groups = []
    
    if use_split_mrs:
        # split MRs into shorter ones
        x_dev, y_dev, dev_groups = split_mrs(x_dev, y_dev, num_variations=num_variations)
        x_test_ref, y_test_ref, test_groups = split_mrs(x_test_ref, y_test_ref, num_variations=num_variations)
   
    elif num_variations > 1:
        x_dev, y_dev = permute_input(x_dev, y_dev, num_permutes=num_variations)
        x_test_ref, y_test_ref = permute_input(x_test_ref, y_test_ref, num_permutes=num_variations)

        
        
    # parse the utterances into lists of words
    y_train = [preprocess_utterance(y) for y in y_train]
    y_dev = [preprocess_utterance(y) for y in y_dev]
    y_test_ref = [preprocess_utterance(y) for y in y_test_ref]

    
    
    # create utterance vocabulary
    distr = FreqDist(np.concatenate(y_train + y_dev))
    y_vocab = distr.most_common(min(len(distr), vocab_size))        # cap the vocabulary size
    y_idx2word = [word[0] for word in y_vocab]
    y_idx2word.insert(0, '-PADDING-')
    y_idx2word.extend(['&slot_val_name&', '&slot_val_food&', '&slot_val_near&'])
    y_idx2word.append('-PERIOD-')
    y_idx2word.append('-NA-')
    y_word2idx = {word: idx for idx, word in enumerate(y_idx2word)}

    
    #Delexicalization
    delex_data(x_train, y_train, update_data_source=True)
    delex_data(x_dev, y_dev, update_data_source=True)
    
    
    #Embeddings
    path='../e2e-dataset'
    path_to_training = path+'/trainset.csv'
    path_to_test = path+'/devset.csv'
    
    embedding = create_embeddings([path_to_training, path_to_test],size=100,min_count=2,window=5,iter=1)
    
    weights = embedding.wv.syn0
    vocab = dict([(k, v.index) for k, v in embedding.wv.vocab.items()])

    
    padding_vec = np.zeros(weights.shape[1])         # embedding vector for "padding" words
    
    # produce sequences of embedding vectors from the meaning representations (MRs) in the training /dev/test set
    x_train_seq =  seq_emb (x_train , embedding, vocab, max_input_seq_len , padding_vec)
    x_dev_seq =  seq_emb (x_dev , embedding, vocab, max_input_seq_len , padding_vec)
    x_test_seq =  seq_emb (x_test_ref , embedding, vocab, max_input_seq_len , padding_vec)

    
    # produce sequences of one-hot vectors from the reference utterances in the training /dev/test set
    y_train_seq= seq_one_hot(y_train, y_word2idx, max_output_seq_len)
    y_dev_seq= seq_one_hot(y_dev, y_word2idx, max_output_seq_len)
    y_test_seq= seq_one_hot(y_test_ref, y_word2idx, max_output_seq_len)


    result = dict()
    result['weights']= weights
    result['x_train_seq']= np.array(x_train_seq)
    result['y_train_seq']= np.array(y_train_seq)
    result['x_dev_seq']= np.array(x_dev_seq)
    result['y_dev_seq']= np.array(y_dev_seq)
    result['x_test_seq']= np.array(x_test_seq)
    result['y_test_seq']= np.array(y_test_seq)
    result['original_mrs_dev']= original_mrs_dev
    result['original_mrs_test']= original_mrs_test
    result['original_sents_dev']= original_sents_dev
    result['original_sents_test']= original_sents_test
    result['test_groups']= test_groups
    result['dev_groups']= dev_groups
    result['y_idx2word']= y_idx2word

    
    return result

# %%
use_split_mrs=True
res = preprocess_data(train, dev, test_ref , vocab_size, max_input_seq_len, max_output_seq_len, num_variations, use_split_mrs)

# %%
use_split_mrs=False
res = preprocess_data(train, dev, test_ref , vocab_size, max_input_seq_len, max_output_seq_len, num_variations, use_split_mrs)

# %% [markdown]
# # 2. Model

# %%
from keras import backend as K
from keras.models import Sequential, Model
from keras.layers import Embedding, LSTM, RepeatVector, Dense, Activation, Input, Flatten, Reshape, Permute, Lambda
from keras.layers.merge import multiply, concatenate
from keras.layers.wrappers import TimeDistributed, Bidirectional

# %%
weights = res['weights']
x_train= res['x_train_seq']
y_train= res['y_train_seq']

x_dev= res['x_dev_seq']
y_dev= res['y_dev_seq']

x_test= res['x_test_seq']
y_test= res['y_test_seq']
y_idx2word= res['y_idx2word']

# %%
# ---- ATTENTION MODEL ----
input = Input(shape=(max_input_seq_len, weights.shape[1]))

# -- ENCODER --
encoder = Bidirectional(LSTM(units=hidden_layer_size,dropout=0.2,recurrent_dropout=0.2,return_sequences=True),merge_mode='concat')(input)

# -- ATTENTION --
flattened = Flatten()(encoder)
attention = []
for i in range(max_output_seq_len):
    weighted = Dense(max_input_seq_len, activation='softmax')(flattened)
    unfolded = Permute([2, 1])(RepeatVector(hidden_layer_size * 2)(weighted))
    multiplied = multiply([encoder, unfolded])
    summed = Lambda(lambda x: K.sum(x, axis=-2))(multiplied)
    attention.append(Reshape((1, hidden_layer_size * 2))(summed))
attention_out = concatenate(attention, axis=-2)

# -- DECODER --
decoder = LSTM(units=hidden_layer_size,dropout=0.2,recurrent_dropout=0.2,return_sequences=True)(attention_out)

decoder = Dense(len(y_idx2word),activation='softmax')(decoder)

model = Model(inputs=input, outputs=decoder)

# ---- COMPILE ----
model.compile(loss='categorical_crossentropy',optimizer='adadelta',metrics=['accuracy'])
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_18 (InputLayer)           (None, 30, 100)      0
# __________________________________________________________________________________________________
# bidirectional_9 (Bidirectional) (None, 30, 1000)     2404000     input_18[0][0]
# __________________________________________________________________________________________________
# flatten_8 (Flatten)             (None, 30000)        0           bidirectional_9[0][0]
# __________________________________________________________________________________________________
# dense_162 (Dense)               (None, 30)           900030      flatten_8[0][0]
# __________________________________________________________________________________________________
# dense_163 (Dense)               (None, 30)           900030      flatten_8[0][0]
# __________________________________________________________________________________________________
# dense_164 (Dense)               (None, 30)           900030      flatten_8[0][0]
# __________________________________________________________________________________________________
# dense_165 (Dense)               (None, 30)           900030      flatten_8[0][0]
# __________________________________________________________________________________________________
# dense_166 (Dense)               (None, 30)           900030      flatten_8[0][0]
# __________________________________________________________________________________________________
# dense_167 (Dense)               (None, 30)           900030      flatten_8[0][0]
# __________________________________________________________________________________________________
# dense_168 (Dense)               (None, 30)           900030      flatten_8[0][0]
# __________________________________________________________________________________________________
# dense_169 (Dense)               (None, 30)           900030      flatten_8[0][0]
# __________________________________________________________________________________________________
# dense_170 (Dense)               (None, 30)           900030      flatten_8[0][0]
# __________________________________________________________________________________________________
# dense_171 (Dense)               (None, 30)           900030      flatten_8[0][0]
# __________________________________________________________________________________________________
# dense_172 (Dense)               (None, 30)           900030      flatten_8[0][0]
# __________________________________________________________________________________________________
# dense_173 (Dense)               (None, 30)           900030      flatten_8[0][0]
# __________________________________________________________________________________________________
# dense_174 (Dense)               (None, 30)           900030      flatten_8[0][0]
# __________________________________________________________________________________________________
# dense_175 (Dense)               (None, 30)           900030      flatten_8[0][0]
# __________________________________________________________________________________________________
# dense_176 (Dense)               (None, 30)           900030      flatten_8[0][0]
# __________________________________________________________________________________________________
# dense_177 (Dense)               (None, 30)           900030      flatten_8[0][0]
# __________________________________________________________________________________________________
# dense_178 (Dense)               (None, 30)           900030      flatten_8[0][0]
# __________________________________________________________________________________________________
# dense_179 (Dense)               (None, 30)           900030      flatten_8[0][0]
# __________________________________________________________________________________________________
# dense_180 (Dense)               (None, 30)           900030      flatten_8[0][0]
# __________________________________________________________________________________________________
# dense_181 (Dense)               (None, 30)           900030      flatten_8[0][0]
# __________________________________________________________________________________________________
# dense_182 (Dense)               (None, 30)           900030      flatten_8[0][0]
# __________________________________________________________________________________________________
# dense_183 (Dense)               (None, 30)           900030      flatten_8[0][0]
# __________________________________________________________________________________________________
# dense_184 (Dense)               (None, 30)           900030      flatten_8[0][0]
# __________________________________________________________________________________________________
# dense_185 (Dense)               (None, 30)           900030      flatten_8[0][0]
# __________________________________________________________________________________________________
# dense_186 (Dense)               (None, 30)           900030      flatten_8[0][0]
# __________________________________________________________________________________________________
# dense_187 (Dense)               (None, 30)           900030      flatten_8[0][0]
# __________________________________________________________________________________________________
# dense_188 (Dense)               (None, 30)           900030      flatten_8[0][0]
# __________________________________________________________________________________________________
# dense_189 (Dense)               (None, 30)           900030      flatten_8[0][0]
# __________________________________________________________________________________________________
# dense_190 (Dense)               (None, 30)           900030      flatten_8[0][0]
# __________________________________________________________________________________________________
# dense_191 (Dense)               (None, 30)           900030      flatten_8[0][0]
# __________________________________________________________________________________________________
# dense_192 (Dense)               (None, 30)           900030      flatten_8[0][0]
# __________________________________________________________________________________________________
# dense_193 (Dense)               (None, 30)           900030      flatten_8[0][0]
# __________________________________________________________________________________________________
# dense_194 (Dense)               (None, 30)           900030      flatten_8[0][0]
# __________________________________________________________________________________________________
# dense_195 (Dense)               (None, 30)           900030      flatten_8[0][0]
# __________________________________________________________________________________________________
# dense_196 (Dense)               (None, 30)           900030      flatten_8[0][0]
# __________________________________________________________________________________________________
# dense_197 (Dense)               (None, 30)           900030      flatten_8[0][0]
# __________________________________________________________________________________________________
# dense_198 (Dense)               (None, 30)           900030      flatten_8[0][0]
# __________________________________________________________________________________________________
# dense_199 (Dense)               (None, 30)           900030      flatten_8[0][0]
# __________________________________________________________________________________________________
# dense_200 (Dense)               (None, 30)           900030      flatten_8[0][0]
# __________________________________________________________________________________________________
# dense_201 (Dense)               (None, 30)           900030      flatten_8[0][0]
# __________________________________________________________________________________________________
# dense_202 (Dense)               (None, 30)           900030      flatten_8[0][0]
# __________________________________________________________________________________________________
# dense_203 (Dense)               (None, 30)           900030      flatten_8[0][0]
# __________________________________________________________________________________________________
# dense_204 (Dense)               (None, 30)           900030      flatten_8[0][0]
# __________________________________________________________________________________________________
# dense_205 (Dense)               (None, 30)           900030      flatten_8[0][0]
# __________________________________________________________________________________________________
# dense_206 (Dense)               (None, 30)           900030      flatten_8[0][0]
# __________________________________________________________________________________________________
# dense_207 (Dense)               (None, 30)           900030      flatten_8[0][0]
# __________________________________________________________________________________________________
# dense_208 (Dense)               (None, 30)           900030      flatten_8[0][0]
# __________________________________________________________________________________________________
# dense_209 (Dense)               (None, 30)           900030      flatten_8[0][0]
# __________________________________________________________________________________________________
# dense_210 (Dense)               (None, 30)           900030      flatten_8[0][0]
# __________________________________________________________________________________________________
# dense_211 (Dense)               (None, 30)           900030      flatten_8[0][0]
# __________________________________________________________________________________________________
# repeat_vector_156 (RepeatVector (None, 1000, 30)     0           dense_162[0][0]
# __________________________________________________________________________________________________
# repeat_vector_157 (RepeatVector (None, 1000, 30)     0           dense_163[0][0]
# __________________________________________________________________________________________________
# repeat_vector_158 (RepeatVector (None, 1000, 30)     0           dense_164[0][0]
# __________________________________________________________________________________________________
# repeat_vector_159 (RepeatVector (None, 1000, 30)     0           dense_165[0][0]
# __________________________________________________________________________________________________
# repeat_vector_160 (RepeatVector (None, 1000, 30)     0           dense_166[0][0]
# __________________________________________________________________________________________________
# repeat_vector_161 (RepeatVector (None, 1000, 30)     0           dense_167[0][0]
# __________________________________________________________________________________________________
# repeat_vector_162 (RepeatVector (None, 1000, 30)     0           dense_168[0][0]
# __________________________________________________________________________________________________
# repeat_vector_163 (RepeatVector (None, 1000, 30)     0           dense_169[0][0]
# __________________________________________________________________________________________________
# repeat_vector_164 (RepeatVector (None, 1000, 30)     0           dense_170[0][0]
# __________________________________________________________________________________________________
# repeat_vector_165 (RepeatVector (None, 1000, 30)     0           dense_171[0][0]
# __________________________________________________________________________________________________
# repeat_vector_166 (RepeatVector (None, 1000, 30)     0           dense_172[0][0]
# __________________________________________________________________________________________________
# repeat_vector_167 (RepeatVector (None, 1000, 30)     0           dense_173[0][0]
# __________________________________________________________________________________________________
# repeat_vector_168 (RepeatVector (None, 1000, 30)     0           dense_174[0][0]
# __________________________________________________________________________________________________
# repeat_vector_169 (RepeatVector (None, 1000, 30)     0           dense_175[0][0]
# __________________________________________________________________________________________________
# repeat_vector_170 (RepeatVector (None, 1000, 30)     0           dense_176[0][0]
# __________________________________________________________________________________________________
# repeat_vector_171 (RepeatVector (None, 1000, 30)     0           dense_177[0][0]
# __________________________________________________________________________________________________
# repeat_vector_172 (RepeatVector (None, 1000, 30)     0           dense_178[0][0]
# __________________________________________________________________________________________________
# repeat_vector_173 (RepeatVector (None, 1000, 30)     0           dense_179[0][0]
# __________________________________________________________________________________________________
# repeat_vector_174 (RepeatVector (None, 1000, 30)     0           dense_180[0][0]
# __________________________________________________________________________________________________
# repeat_vector_175 (RepeatVector (None, 1000, 30)     0           dense_181[0][0]
# __________________________________________________________________________________________________
# repeat_vector_176 (RepeatVector (None, 1000, 30)     0           dense_182[0][0]
# __________________________________________________________________________________________________
# repeat_vector_177 (RepeatVector (None, 1000, 30)     0           dense_183[0][0]
# __________________________________________________________________________________________________
# repeat_vector_178 (RepeatVector (None, 1000, 30)     0           dense_184[0][0]
# __________________________________________________________________________________________________
# repeat_vector_179 (RepeatVector (None, 1000, 30)     0           dense_185[0][0]
# __________________________________________________________________________________________________
# repeat_vector_180 (RepeatVector (None, 1000, 30)     0           dense_186[0][0]
# __________________________________________________________________________________________________
# repeat_vector_181 (RepeatVector (None, 1000, 30)     0           dense_187[0][0]
# __________________________________________________________________________________________________
# repeat_vector_182 (RepeatVector (None, 1000, 30)     0           dense_188[0][0]
# __________________________________________________________________________________________________
# repeat_vector_183 (RepeatVector (None, 1000, 30)     0           dense_189[0][0]
# __________________________________________________________________________________________________
# repeat_vector_184 (RepeatVector (None, 1000, 30)     0           dense_190[0][0]
# __________________________________________________________________________________________________
# repeat_vector_185 (RepeatVector (None, 1000, 30)     0           dense_191[0][0]
# __________________________________________________________________________________________________
# repeat_vector_186 (RepeatVector (None, 1000, 30)     0           dense_192[0][0]
# __________________________________________________________________________________________________
# repeat_vector_187 (RepeatVector (None, 1000, 30)     0           dense_193[0][0]
# __________________________________________________________________________________________________
# repeat_vector_188 (RepeatVector (None, 1000, 30)     0           dense_194[0][0]
# __________________________________________________________________________________________________
# repeat_vector_189 (RepeatVector (None, 1000, 30)     0           dense_195[0][0]
# __________________________________________________________________________________________________
# repeat_vector_190 (RepeatVector (None, 1000, 30)     0           dense_196[0][0]
# __________________________________________________________________________________________________
# repeat_vector_191 (RepeatVector (None, 1000, 30)     0           dense_197[0][0]
# __________________________________________________________________________________________________
# repeat_vector_192 (RepeatVector (None, 1000, 30)     0           dense_198[0][0]
# __________________________________________________________________________________________________
# repeat_vector_193 (RepeatVector (None, 1000, 30)     0           dense_199[0][0]
# __________________________________________________________________________________________________
# repeat_vector_194 (RepeatVector (None, 1000, 30)     0           dense_200[0][0]
# __________________________________________________________________________________________________
# repeat_vector_195 (RepeatVector (None, 1000, 30)     0           dense_201[0][0]
# __________________________________________________________________________________________________
# repeat_vector_196 (RepeatVector (None, 1000, 30)     0           dense_202[0][0]
# __________________________________________________________________________________________________
# repeat_vector_197 (RepeatVector (None, 1000, 30)     0           dense_203[0][0]
# __________________________________________________________________________________________________
# repeat_vector_198 (RepeatVector (None, 1000, 30)     0           dense_204[0][0]
# __________________________________________________________________________________________________
# repeat_vector_199 (RepeatVector (None, 1000, 30)     0           dense_205[0][0]
# __________________________________________________________________________________________________
# repeat_vector_200 (RepeatVector (None, 1000, 30)     0           dense_206[0][0]
# __________________________________________________________________________________________________
# repeat_vector_201 (RepeatVector (None, 1000, 30)     0           dense_207[0][0]
# __________________________________________________________________________________________________
# repeat_vector_202 (RepeatVector (None, 1000, 30)     0           dense_208[0][0]
# __________________________________________________________________________________________________
# repeat_vector_203 (RepeatVector (None, 1000, 30)     0           dense_209[0][0]
# __________________________________________________________________________________________________
# repeat_vector_204 (RepeatVector (None, 1000, 30)     0           dense_210[0][0]
# __________________________________________________________________________________________________
# repeat_vector_205 (RepeatVector (None, 1000, 30)     0           dense_211[0][0]
# __________________________________________________________________________________________________
# permute_156 (Permute)           (None, 30, 1000)     0           repeat_vector_156[0][0]
# __________________________________________________________________________________________________
# permute_157 (Permute)           (None, 30, 1000)     0           repeat_vector_157[0][0]
# __________________________________________________________________________________________________
# permute_158 (Permute)           (None, 30, 1000)     0           repeat_vector_158[0][0]
# __________________________________________________________________________________________________
# permute_159 (Permute)           (None, 30, 1000)     0           repeat_vector_159[0][0]
# __________________________________________________________________________________________________
# permute_160 (Permute)           (None, 30, 1000)     0           repeat_vector_160[0][0]
# __________________________________________________________________________________________________
# permute_161 (Permute)           (None, 30, 1000)     0           repeat_vector_161[0][0]
# __________________________________________________________________________________________________
# permute_162 (Permute)           (None, 30, 1000)     0           repeat_vector_162[0][0]
# __________________________________________________________________________________________________
# permute_163 (Permute)           (None, 30, 1000)     0           repeat_vector_163[0][0]
# __________________________________________________________________________________________________
# permute_164 (Permute)           (None, 30, 1000)     0           repeat_vector_164[0][0]
# __________________________________________________________________________________________________
# permute_165 (Permute)           (None, 30, 1000)     0           repeat_vector_165[0][0]
# __________________________________________________________________________________________________
# permute_166 (Permute)           (None, 30, 1000)     0           repeat_vector_166[0][0]
# __________________________________________________________________________________________________
# permute_167 (Permute)           (None, 30, 1000)     0           repeat_vector_167[0][0]
# __________________________________________________________________________________________________
# permute_168 (Permute)           (None, 30, 1000)     0           repeat_vector_168[0][0]
# __________________________________________________________________________________________________
# permute_169 (Permute)           (None, 30, 1000)     0           repeat_vector_169[0][0]
# __________________________________________________________________________________________________
# permute_170 (Permute)           (None, 30, 1000)     0           repeat_vector_170[0][0]
# __________________________________________________________________________________________________
# permute_171 (Permute)           (None, 30, 1000)     0           repeat_vector_171[0][0]
# __________________________________________________________________________________________________
# permute_172 (Permute)           (None, 30, 1000)     0           repeat_vector_172[0][0]
# __________________________________________________________________________________________________
# permute_173 (Permute)           (None, 30, 1000)     0           repeat_vector_173[0][0]
# __________________________________________________________________________________________________
# permute_174 (Permute)           (None, 30, 1000)     0           repeat_vector_174[0][0]
# __________________________________________________________________________________________________
# permute_175 (Permute)           (None, 30, 1000)     0           repeat_vector_175[0][0]
# __________________________________________________________________________________________________
# permute_176 (Permute)           (None, 30, 1000)     0           repeat_vector_176[0][0]
# __________________________________________________________________________________________________
# permute_177 (Permute)           (None, 30, 1000)     0           repeat_vector_177[0][0]
# __________________________________________________________________________________________________
# permute_178 (Permute)           (None, 30, 1000)     0           repeat_vector_178[0][0]
# __________________________________________________________________________________________________
# permute_179 (Permute)           (None, 30, 1000)     0           repeat_vector_179[0][0]
# __________________________________________________________________________________________________
# permute_180 (Permute)           (None, 30, 1000)     0           repeat_vector_180[0][0]
# __________________________________________________________________________________________________
# permute_181 (Permute)           (None, 30, 1000)     0           repeat_vector_181[0][0]
# __________________________________________________________________________________________________
# permute_182 (Permute)           (None, 30, 1000)     0           repeat_vector_182[0][0]
# __________________________________________________________________________________________________
# permute_183 (Permute)           (None, 30, 1000)     0           repeat_vector_183[0][0]
# __________________________________________________________________________________________________
# permute_184 (Permute)           (None, 30, 1000)     0           repeat_vector_184[0][0]
# __________________________________________________________________________________________________
# permute_185 (Permute)           (None, 30, 1000)     0           repeat_vector_185[0][0]
# __________________________________________________________________________________________________
# permute_186 (Permute)           (None, 30, 1000)     0           repeat_vector_186[0][0]
# __________________________________________________________________________________________________
# permute_187 (Permute)           (None, 30, 1000)     0           repeat_vector_187[0][0]
# __________________________________________________________________________________________________
# permute_188 (Permute)           (None, 30, 1000)     0           repeat_vector_188[0][0]
# __________________________________________________________________________________________________
# permute_189 (Permute)           (None, 30, 1000)     0           repeat_vector_189[0][0]
# __________________________________________________________________________________________________
# permute_190 (Permute)           (None, 30, 1000)     0           repeat_vector_190[0][0]
# __________________________________________________________________________________________________
# permute_191 (Permute)           (None, 30, 1000)     0           repeat_vector_191[0][0]
# __________________________________________________________________________________________________
# permute_192 (Permute)           (None, 30, 1000)     0           repeat_vector_192[0][0]
# __________________________________________________________________________________________________
# permute_193 (Permute)           (None, 30, 1000)     0           repeat_vector_193[0][0]
# __________________________________________________________________________________________________
# permute_194 (Permute)           (None, 30, 1000)     0           repeat_vector_194[0][0]
# __________________________________________________________________________________________________
# permute_195 (Permute)           (None, 30, 1000)     0           repeat_vector_195[0][0]
# __________________________________________________________________________________________________
# permute_196 (Permute)           (None, 30, 1000)     0           repeat_vector_196[0][0]
# __________________________________________________________________________________________________
# permute_197 (Permute)           (None, 30, 1000)     0           repeat_vector_197[0][0]
# __________________________________________________________________________________________________
# permute_198 (Permute)           (None, 30, 1000)     0           repeat_vector_198[0][0]
# __________________________________________________________________________________________________
# permute_199 (Permute)           (None, 30, 1000)     0           repeat_vector_199[0][0]
# __________________________________________________________________________________________________
# permute_200 (Permute)           (None, 30, 1000)     0           repeat_vector_200[0][0]
# __________________________________________________________________________________________________
# permute_201 (Permute)           (None, 30, 1000)     0           repeat_vector_201[0][0]
# __________________________________________________________________________________________________
# permute_202 (Permute)           (None, 30, 1000)     0           repeat_vector_202[0][0]
# __________________________________________________________________________________________________
# permute_203 (Permute)           (None, 30, 1000)     0           repeat_vector_203[0][0]
# __________________________________________________________________________________________________
# permute_204 (Permute)           (None, 30, 1000)     0           repeat_vector_204[0][0]
# __________________________________________________________________________________________________
# permute_205 (Permute)           (None, 30, 1000)     0           repeat_vector_205[0][0]
# __________________________________________________________________________________________________
# multiply_156 (Multiply)         (None, 30, 1000)     0           bidirectional_9[0][0]
#                                                                  permute_156[0][0]
# __________________________________________________________________________________________________
# multiply_157 (Multiply)         (None, 30, 1000)     0           bidirectional_9[0][0]
#                                                                  permute_157[0][0]
# __________________________________________________________________________________________________
# multiply_158 (Multiply)         (None, 30, 1000)     0           bidirectional_9[0][0]
#                                                                  permute_158[0][0]
# __________________________________________________________________________________________________
# multiply_159 (Multiply)         (None, 30, 1000)     0           bidirectional_9[0][0]
#                                                                  permute_159[0][0]
# __________________________________________________________________________________________________
# multiply_160 (Multiply)         (None, 30, 1000)     0           bidirectional_9[0][0]
#                                                                  permute_160[0][0]
# __________________________________________________________________________________________________
# multiply_161 (Multiply)         (None, 30, 1000)     0           bidirectional_9[0][0]
#                                                                  permute_161[0][0]
# __________________________________________________________________________________________________
# multiply_162 (Multiply)         (None, 30, 1000)     0           bidirectional_9[0][0]
#                                                                  permute_162[0][0]
# __________________________________________________________________________________________________
# multiply_163 (Multiply)         (None, 30, 1000)     0           bidirectional_9[0][0]
#                                                                  permute_163[0][0]
# __________________________________________________________________________________________________
# multiply_164 (Multiply)         (None, 30, 1000)     0           bidirectional_9[0][0]
#                                                                  permute_164[0][0]
# __________________________________________________________________________________________________
# multiply_165 (Multiply)         (None, 30, 1000)     0           bidirectional_9[0][0]
#                                                                  permute_165[0][0]
# __________________________________________________________________________________________________
# multiply_166 (Multiply)         (None, 30, 1000)     0           bidirectional_9[0][0]
#                                                                  permute_166[0][0]
# __________________________________________________________________________________________________
# multiply_167 (Multiply)         (None, 30, 1000)     0           bidirectional_9[0][0]
#                                                                  permute_167[0][0]
# __________________________________________________________________________________________________
# multiply_168 (Multiply)         (None, 30, 1000)     0           bidirectional_9[0][0]
#                                                                  permute_168[0][0]
# __________________________________________________________________________________________________
# multiply_169 (Multiply)         (None, 30, 1000)     0           bidirectional_9[0][0]
#                                                                  permute_169[0][0]
# __________________________________________________________________________________________________
# multiply_170 (Multiply)         (None, 30, 1000)     0           bidirectional_9[0][0]
#                                                                  permute_170[0][0]
# __________________________________________________________________________________________________
# multiply_171 (Multiply)         (None, 30, 1000)     0           bidirectional_9[0][0]
#                                                                  permute_171[0][0]
# __________________________________________________________________________________________________
# multiply_172 (Multiply)         (None, 30, 1000)     0           bidirectional_9[0][0]
#                                                                  permute_172[0][0]
# __________________________________________________________________________________________________
# multiply_173 (Multiply)         (None, 30, 1000)     0           bidirectional_9[0][0]
#                                                                  permute_173[0][0]
# __________________________________________________________________________________________________
# multiply_174 (Multiply)         (None, 30, 1000)     0           bidirectional_9[0][0]
#                                                                  permute_174[0][0]
# __________________________________________________________________________________________________
# multiply_175 (Multiply)         (None, 30, 1000)     0           bidirectional_9[0][0]
#                                                                  permute_175[0][0]
# __________________________________________________________________________________________________
# multiply_176 (Multiply)         (None, 30, 1000)     0           bidirectional_9[0][0]
#                                                                  permute_176[0][0]
# __________________________________________________________________________________________________
# multiply_177 (Multiply)         (None, 30, 1000)     0           bidirectional_9[0][0]
#                                                                  permute_177[0][0]
# __________________________________________________________________________________________________
# multiply_178 (Multiply)         (None, 30, 1000)     0           bidirectional_9[0][0]
#                                                                  permute_178[0][0]
# __________________________________________________________________________________________________
# multiply_179 (Multiply)         (None, 30, 1000)     0           bidirectional_9[0][0]
#                                                                  permute_179[0][0]
# __________________________________________________________________________________________________
# multiply_180 (Multiply)         (None, 30, 1000)     0           bidirectional_9[0][0]
#                                                                  permute_180[0][0]
# __________________________________________________________________________________________________
# multiply_181 (Multiply)         (None, 30, 1000)     0           bidirectional_9[0][0]
#                                                                  permute_181[0][0]
# __________________________________________________________________________________________________
# multiply_182 (Multiply)         (None, 30, 1000)     0           bidirectional_9[0][0]
#                                                                  permute_182[0][0]
# __________________________________________________________________________________________________
# multiply_183 (Multiply)         (None, 30, 1000)     0           bidirectional_9[0][0]
#                                                                  permute_183[0][0]
# __________________________________________________________________________________________________
# multiply_184 (Multiply)         (None, 30, 1000)     0           bidirectional_9[0][0]
#                                                                  permute_184[0][0]
# __________________________________________________________________________________________________
# multiply_185 (Multiply)         (None, 30, 1000)     0           bidirectional_9[0][0]
#                                                                  permute_185[0][0]
# __________________________________________________________________________________________________
# multiply_186 (Multiply)         (None, 30, 1000)     0           bidirectional_9[0][0]
#                                                                  permute_186[0][0]
# __________________________________________________________________________________________________
# multiply_187 (Multiply)         (None, 30, 1000)     0           bidirectional_9[0][0]
#                                                                  permute_187[0][0]
# __________________________________________________________________________________________________
# multiply_188 (Multiply)         (None, 30, 1000)     0           bidirectional_9[0][0]
#                                                                  permute_188[0][0]
# __________________________________________________________________________________________________
# multiply_189 (Multiply)         (None, 30, 1000)     0           bidirectional_9[0][0]
#                                                                  permute_189[0][0]
# __________________________________________________________________________________________________
# multiply_190 (Multiply)         (None, 30, 1000)     0           bidirectional_9[0][0]
#                                                                  permute_190[0][0]
# __________________________________________________________________________________________________
# multiply_191 (Multiply)         (None, 30, 1000)     0           bidirectional_9[0][0]
#                                                                  permute_191[0][0]
# __________________________________________________________________________________________________
# multiply_192 (Multiply)         (None, 30, 1000)     0           bidirectional_9[0][0]
#                                                                  permute_192[0][0]
# __________________________________________________________________________________________________
# multiply_193 (Multiply)         (None, 30, 1000)     0           bidirectional_9[0][0]
#                                                                  permute_193[0][0]
# __________________________________________________________________________________________________
# multiply_194 (Multiply)         (None, 30, 1000)     0           bidirectional_9[0][0]
#                                                                  permute_194[0][0]
# __________________________________________________________________________________________________
# multiply_195 (Multiply)         (None, 30, 1000)     0           bidirectional_9[0][0]
#                                                                  permute_195[0][0]
# __________________________________________________________________________________________________
# multiply_196 (Multiply)         (None, 30, 1000)     0           bidirectional_9[0][0]
#                                                                  permute_196[0][0]
# __________________________________________________________________________________________________
# multiply_197 (Multiply)         (None, 30, 1000)     0           bidirectional_9[0][0]
#                                                                  permute_197[0][0]
# __________________________________________________________________________________________________
# multiply_198 (Multiply)         (None, 30, 1000)     0           bidirectional_9[0][0]
#                                                                  permute_198[0][0]
# __________________________________________________________________________________________________
# multiply_199 (Multiply)         (None, 30, 1000)     0           bidirectional_9[0][0]
#                                                                  permute_199[0][0]
# __________________________________________________________________________________________________
# multiply_200 (Multiply)         (None, 30, 1000)     0           bidirectional_9[0][0]
#                                                                  permute_200[0][0]
# __________________________________________________________________________________________________
# multiply_201 (Multiply)         (None, 30, 1000)     0           bidirectional_9[0][0]
#                                                                  permute_201[0][0]
# __________________________________________________________________________________________________
# multiply_202 (Multiply)         (None, 30, 1000)     0           bidirectional_9[0][0]
#                                                                  permute_202[0][0]
# __________________________________________________________________________________________________
# multiply_203 (Multiply)         (None, 30, 1000)     0           bidirectional_9[0][0]
#                                                                  permute_203[0][0]
# __________________________________________________________________________________________________
# multiply_204 (Multiply)         (None, 30, 1000)     0           bidirectional_9[0][0]
#                                                                  permute_204[0][0]
# __________________________________________________________________________________________________
# multiply_205 (Multiply)         (None, 30, 1000)     0           bidirectional_9[0][0]
#                                                                  permute_205[0][0]
# __________________________________________________________________________________________________
# lambda_156 (Lambda)             (None, 1000)         0           multiply_156[0][0]
# __________________________________________________________________________________________________
# lambda_157 (Lambda)             (None, 1000)         0           multiply_157[0][0]
# __________________________________________________________________________________________________
# lambda_158 (Lambda)             (None, 1000)         0           multiply_158[0][0]
# __________________________________________________________________________________________________
# lambda_159 (Lambda)             (None, 1000)         0           multiply_159[0][0]
# __________________________________________________________________________________________________
# lambda_160 (Lambda)             (None, 1000)         0           multiply_160[0][0]
# __________________________________________________________________________________________________
# lambda_161 (Lambda)             (None, 1000)         0           multiply_161[0][0]
# __________________________________________________________________________________________________
# lambda_162 (Lambda)             (None, 1000)         0           multiply_162[0][0]
# __________________________________________________________________________________________________
# lambda_163 (Lambda)             (None, 1000)         0           multiply_163[0][0]
# __________________________________________________________________________________________________
# lambda_164 (Lambda)             (None, 1000)         0           multiply_164[0][0]
# __________________________________________________________________________________________________
# lambda_165 (Lambda)             (None, 1000)         0           multiply_165[0][0]
# __________________________________________________________________________________________________
# lambda_166 (Lambda)             (None, 1000)         0           multiply_166[0][0]
# __________________________________________________________________________________________________
# lambda_167 (Lambda)             (None, 1000)         0           multiply_167[0][0]
# __________________________________________________________________________________________________
# lambda_168 (Lambda)             (None, 1000)         0           multiply_168[0][0]
# ...
# lambda_204 (Lambda)             (None, 1000)         0           multiply_204[0][0]
# __________________________________________________________________________________________________
# lambda_205 (Lambda)             (None, 1000)         0           multiply_205[0][0]
# __________________________________________________________________________________________________
# reshape_156 (Reshape)           (None, 1, 1000)      0           lambda_156[0][0]
# __________________________________________________________________________________________________
# reshape_157 (Reshape)           (None, 1, 1000)      0           lambda_157[0][0]
# __________________________________________________________________________________________________
# reshape_158 (Reshape)           (None, 1, 1000)      0           lambda_158[0][0]
# __________________________________________________________________________________________________
# reshape_159 (Reshape)           (None, 1, 1000)      0           lambda_159[0][0]
# __________________________________________________________________________________________________
# reshape_160 (Reshape)           (None, 1, 1000)      0           lambda_160[0][0]
# __________________________________________________________________________________________________
# reshape_161 (Reshape)           (None, 1, 1000)      0           lambda_161[0][0]
# __________________________________________________________________________________________________
# reshape_162 (Reshape)           (None, 1, 1000)      0           lambda_162[0][0]
# __________________________________________________________________________________________________
# reshape_163 (Reshape)           (None, 1, 1000)      0           lambda_163[0][0]
# __________________________________________________________________________________________________
# reshape_164 (Reshape)           (None, 1, 1000)      0           lambda_164[0][0]
# __________________________________________________________________________________________________
# reshape_165 (Reshape)           (None, 1, 1000)      0           lambda_165[0][0]
# __________________________________________________________________________________________________
# reshape_166 (Reshape)           (None, 1, 1000)      0           lambda_166[0][0]
# __________________________________________________________________________________________________
# reshape_167 (Reshape)           (None, 1, 1000)      0           lambda_167[0][0]
# __________________________________________________________________________________________________
# reshape_168 (Reshape)           (None, 1, 1000)      0           lambda_168[0][0]
# __________________________________________________________________________________________________
# reshape_169 (Reshape)           (None, 1, 1000)      0           lambda_169[0][0]
# __________________________________________________________________________________________________
# reshape_170 (Reshape)           (None, 1, 1000)      0           lambda_170[0][0]
# __________________________________________________________________________________________________
# reshape_171 (Reshape)           (None, 1, 1000)      0           lambda_171[0][0]
# __________________________________________________________________________________________________
# reshape_172 (Reshape)           (None, 1, 1000)      0           lambda_172[0][0]
# __________________________________________________________________________________________________
# reshape_173 (Reshape)           (None, 1, 1000)      0           lambda_173[0][0]
# __________________________________________________________________________________________________
# reshape_174 (Reshape)           (None, 1, 1000)      0           lambda_174[0][0]
# __________________________________________________________________________________________________
# reshape_175 (Reshape)           (None, 1, 1000)      0           lambda_175[0][0]
# __________________________________________________________________________________________________
# reshape_176 (Reshape)           (None, 1, 1000)      0           lambda_176[0][0]
# __________________________________________________________________________________________________
# reshape_177 (Reshape)           (None, 1, 1000)      0           lambda_177[0][0]
# __________________________________________________________________________________________________
# reshape_178 (Reshape)           (None, 1, 1000)      0           lambda_178[0][0]
# __________________________________________________________________________________________________
# reshape_179 (Reshape)           (None, 1, 1000)      0           lambda_179[0][0]
# __________________________________________________________________________________________________
# reshape_180 (Reshape)           (None, 1, 1000)      0           lambda_180[0][0]
# __________________________________________________________________________________________________
# reshape_181 (Reshape)           (None, 1, 1000)      0           lambda_181[0][0]
# __________________________________________________________________________________________________
# reshape_182 (Reshape)           (None, 1, 1000)      0           lambda_182[0][0]
# __________________________________________________________________________________________________
# reshape_183 (Reshape)           (None, 1, 1000)      0           lambda_183[0][0]
# __________________________________________________________________________________________________
# reshape_184 (Reshape)           (None, 1, 1000)      0           lambda_184[0][0]
# __________________________________________________________________________________________________
# reshape_185 (Reshape)           (None, 1, 1000)      0           lambda_185[0][0]
# __________________________________________________________________________________________________
# reshape_186 (Reshape)           (None, 1, 1000)      0           lambda_186[0][0]
# __________________________________________________________________________________________________
# reshape_187 (Reshape)           (None, 1, 1000)      0           lambda_187[0][0]
# __________________________________________________________________________________________________
# reshape_188 (Reshape)           (None, 1, 1000)      0           lambda_188[0][0]
# __________________________________________________________________________________________________
# reshape_189 (Reshape)           (None, 1, 1000)      0           lambda_189[0][0]
# __________________________________________________________________________________________________
# reshape_190 (Reshape)           (None, 1, 1000)      0           lambda_190[0][0]
# __________________________________________________________________________________________________
# reshape_191 (Reshape)           (None, 1, 1000)      0           lambda_191[0][0]
# __________________________________________________________________________________________________
# reshape_192 (Reshape)           (None, 1, 1000)      0           lambda_192[0][0]
# __________________________________________________________________________________________________
# reshape_193 (Reshape)           (None, 1, 1000)      0           lambda_193[0][0]
# __________________________________________________________________________________________________
# reshape_194 (Reshape)           (None, 1, 1000)      0           lambda_194[0][0]
# __________________________________________________________________________________________________
# reshape_195 (Reshape)           (None, 1, 1000)      0           lambda_195[0][0]
# __________________________________________________________________________________________________
# reshape_196 (Reshape)           (None, 1, 1000)      0           lambda_196[0][0]
# __________________________________________________________________________________________________
# reshape_197 (Reshape)           (None, 1, 1000)      0           lambda_197[0][0]
# __________________________________________________________________________________________________
# reshape_198 (Reshape)           (None, 1, 1000)      0           lambda_198[0][0]
# __________________________________________________________________________________________________
# reshape_199 (Reshape)           (None, 1, 1000)      0           lambda_199[0][0]
# __________________________________________________________________________________________________
# reshape_200 (Reshape)           (None, 1, 1000)      0           lambda_200[0][0]
# __________________________________________________________________________________________________
# reshape_201 (Reshape)           (None, 1, 1000)      0           lambda_201[0][0]
# __________________________________________________________________________________________________
# reshape_202 (Reshape)           (None, 1, 1000)      0           lambda_202[0][0]
# __________________________________________________________________________________________________
# reshape_203 (Reshape)           (None, 1, 1000)      0           lambda_203[0][0]
# __________________________________________________________________________________________________
# reshape_204 (Reshape)           (None, 1, 1000)      0           lambda_204[0][0]
# __________________________________________________________________________________________________
# reshape_205 (Reshape)           (None, 1, 1000)      0           lambda_205[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 50, 1000)     0           reshape_156[0][0]
#                                                                  reshape_157[0][0]
#                                                                  reshape_158[0][0]
#                                                                  reshape_159[0][0]
#                                                                  reshape_160[0][0]
#                                                                  reshape_161[0][0]
#                                                                  reshape_162[0][0]
#                                                                  reshape_163[0][0]
#                                                                  reshape_164[0][0]
#                                                                  reshape_165[0][0]
#                                                                  reshape_166[0][0]
#                                                                  reshape_167[0][0]
#                                                                  reshape_168[0][0]
#                                                                  reshape_169[0][0]
#                                                                  reshape_170[0][0]
#                                                                  reshape_171[0][0]
#                                                                  reshape_172[0][0]
#                                                                  reshape_173[0][0]
#                                                                  reshape_174[0][0]
#                                                                  reshape_175[0][0]
#                                                                  reshape_176[0][0]
#                                                                  reshape_177[0][0]
#                                                                  reshape_178[0][0]
#                                                                  reshape_179[0][0]
#                                                                  reshape_180[0][0]
#                                                                  reshape_181[0][0]
#                                                                  reshape_182[0][0]
#                                                                  reshape_183[0][0]
#                                                                  reshape_184[0][0]
#                                                                  reshape_185[0][0]
#                                                                  reshape_186[0][0]
#                                                                  reshape_187[0][0]
#                                                                  reshape_188[0][0]
#                                                                  reshape_189[0][0]
#                                                                  reshape_190[0][0]
#                                                                  reshape_191[0][0]
#                                                                  reshape_192[0][0]
#                                                                  reshape_193[0][0]
#                                                                  reshape_194[0][0]
#                                                                  reshape_195[0][0]
#                                                                  reshape_196[0][0]
#                                                                  reshape_197[0][0]
#                                                                  reshape_198[0][0]
#                                                                  reshape_199[0][0]
#                                                                  reshape_200[0][0]
#                                                                  reshape_201[0][0]
#                                                                  reshape_202[0][0]
#                                                                  reshape_203[0][0]
#                                                                  reshape_204[0][0]
#                                                                  reshape_205[0][0]
# __________________________________________________________________________________________________
# lstm_18 (LSTM)                  (None, 50, 500)      3002000     concatenate_7[0][0]
# __________________________________________________________________________________________________
# dense_212 (Dense)               (None, 50, 2655)     1330155     lstm_18[0][0]
# ==================================================================================================
# Total params: 51,737,655
# Trainable params: 51,737,655
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model = Sequential()

input = Input(shape=(max_input_seq_len, weights.shape[1]))

# -- ENCODER --

model.add(Bidirectional(LSTM(units=weights.shape[1],
                             dropout=0.2,
                             recurrent_dropout=0.2,
                             return_sequences=ret_seq_first_layer),
                             input_shape=(max_input_seq_len, weights.shape[1])))


## -- DECODER --
model.add(RepeatVector(max_output_seq_len))
model.add(LSTM(units=weights.shape[1],
                       dropout=0.2,
                       recurrent_dropout=0.2,
                       return_sequences=True))
model.add(TimeDistributed(Dense(len(y_idx2word),
                                    activation='softmax')))


# ---- COMPILE ----
model.compile(loss='categorical_crossentropy',optimizer='adadelta',metrics=['accuracy'])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_21 (Bidirectio (None, 200)               160800
# _________________________________________________________________
# repeat_vector_216 (RepeatVec (None, 50, 200)           0
# _________________________________________________________________
# lstm_39 (LSTM)               (None, 50, 100)           120400
# _________________________________________________________________
# time_distributed_4 (TimeDist (None, 50, 2655)          268155
# =================================================================
# Total params: 549,355
# Trainable params: 549,355
# Non-trainable params: 0
# _________________________________________________________________

# %%
# ---- TRAIN ----
print('\nTraining...')
model.fit(x_train, y_train, batch_size=64,epochs=2, validation_data=(x_dev, y_dev))
# Out:
# Training...
# Train on 42061 samples, validate on 38598 samples
# Epoch 1/2
# 42061/42061 [==============================] - 971s 23ms/step - loss: 1.8110 - acc: 0.6654 - val_loss: 2.4309 - val_acc: 0.5725
# Epoch 2/2
# 42061/42061 [==============================] - 950s 23ms/step - loss: 1.6632 - acc: 0.6789 - val_loss: 2.9838 - val_acc: 0.5863

# %%
 # ---- Test ----
print('\nTesting...')
score, acc = model.evaluate(x_test, y_test)
print('Test score:', score)
print('Test accuracy:', acc)
# Out:
# Testing...
#  3968/45516 [=>............................] - ETA: 3:55
